# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# In the python code, I'm using these parameters:
# ```
# num = 1000
# k = 16
# np.random.seed(123)
# g = make_saturn(num, r = 10)
# k_min,k_max,x = make_edge_graph(g, k, False)
# ```
# with the following output:
#
# <b>min: 16 max: 30 avg: 19.766</b>

# %%
perimeter = list(map(int, open("perimeter.data").read().split()))
figsize(15,5)
subplot(121)
plot(perimeter);
subplot(122)
hist(perimeter, color = 'grey');

# %% [markdown]
# Now with num = 2000, everything else the same. I get the following output:
#
# <b>min: 16 max: 30 avg: 19.764</b>

# %%
perimeter = list(map(int, open("perimeter.data").read().split()))
figsize(15,5)
subplot(121)
plot(perimeter);
subplot(122)
hist(perimeter, color = 'grey');

# %% [markdown]
# Now with num = 4000, everything else the same. I get the following output:
#
# <b>min: 16 max: 29 avg: 19.4345</b>

# %%
perimeter = list(map(int, open("perimeter.data").read().split()))
figsize(15,5)
subplot(121)
plot(perimeter);
subplot(122)
hist(perimeter, color = 'grey');

# %% [markdown]
# Finally, with num = 8000, I get the following output:
#
# <b>min: 16 max: 28 avg: 19.096</b>

# %%
perimeter = list(map(int, open("perimeter.data").read().split()))
figsize(15,5)
subplot(121)
plot(perimeter);
subplot(122)
hist(perimeter, color = 'grey');

# %%
#my newer algorithm with alpha 0.8 and I switched the order of the planet and the ring
#now the first large hump is the planet
#and the second almost flat-line is the ring
perimeter = list(map(int, open("perimeter.data").read().split()))
figsize(15,5)
subplot(121)
plot(perimeter);
subplot(122)
hist(perimeter, color = 'grey');

# %%
#my fast algorithm: look_up 
#this is without alpha
#and therefore makes a whole bunch of clusters
perimeter = list(map(int, open("perimeter.data").read().split()))
figsize(15,5)
subplot(121)
plot(perimeter);
subplot(122)
hist(perimeter, color = 'grey');
